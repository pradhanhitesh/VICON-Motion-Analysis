# %% [markdown]
# <a href="https://colab.research.google.com/github/pradhanhitesh/VICON-Motion-Analysis/blob/main/KneeAngle_RightLegRaising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   **COURSE:** ES656 Human Robot Interaction
#
#   **INSTITUTE:** Indian Institute of Technology, Gandhinagar
#
#   **AUTHOR:** Srisai Rakesh Kottu, Hitesh Pradhan
#
# **MOTION:** Right Leg Raising
#
# This code estimates the knee-joint angle in saggital plane.

# %%
import csv 
import math 
from matplotlib import pyplot as plt

# %%
file = open("Neel_RightLegRaising.csv")
csvreader = csv.reader(file)

header = next(csvreader)
print(header)

rows = []

for row in csvreader:
    rows.append(row)

#print(rows[0])
file.close
# Out:
# ['-430.781616', '248.532867', '664.327698', '-427.888947', '288.395569', '480.915955', '-462.237274', '309.499146', '287.906464']
# <function TextIOWrapper.close>

# %%
#ref ['RTHI_X', 'RTHI_Y', 'RTHI_Z', 'RKNE_X', 'RKNE_Y', 'RKNE_Z', 'RTIB_X', 'RTIB_Y', 'RTIB_Z']
#       0          1         2         3          4        5         6         7         8

print (rows[1])
angle = []
def slope(x1, y1, x2, y2):
    return (float)(y2-y1)/(x2-x1)

print(len(rows))

for i in range(1849):
    
    m1 = slope(float(rows[i][1]),float(rows[i][2]),float(rows[i][4]),float(rows[i][5]))
    #print(m1)
    m2 = slope(float(rows[i][4]),float(rows[i][5]),float(rows[i][7]),float(rows[i][8]))
    #print(m2)

    tanKnee = (m1-m2)/(1+(m1*m2))
    #print(tanKnee)

    KneeAng = math.degrees(math.atan(tanKnee))
    angle.append(170+KneeAng)
    #print(KneeAng)

plt.plot(angle)
plt.grid()
plt.xlabel("Frames (200fps)")
plt.ylabel("Knee Angle")
# Out:
# ['-430.807343', '248.557251', '664.348328', '-427.929443', '288.379883', '480.926025', '-462.261932', '309.505005', '287.914978']
# 1999
# Text(0, 0.5, 'Knee Angle')
